# %%
import sys
import os

sgpp_folder = "../SGpp"
# -*- coding: utf-8 -*-
"""gettingStarted.ipynb

Automatically generated by Colaboratory.

# Getting SGpp 
... in Google colab.
"""

! apt-get install scons swig # build tools for sgpp
! git clone https://github.com/SGpp/SGpp.git
! cd SGpp && git checkout b0c10d35c50f147f17df958ff37152b3a13e901a

# install sgpp -- start early, takes > 30min!
# !cd SGpp  && scons -j16 SG_BASE=1 SG_COMBIGRID=1 SG_DATADRIVEN=1 SG_MISC=1 SG_OPTIMIZATION=1 SG_PDE=1 SG_QUADRATURE=1 SG_SOLVER=1 SG_JAVA=0 SG_MATLAB=0 SG_PYTHON=1 COMPILE_BOOST_TESTS=0 RUN_BOOST_TESTS=0

# Make python interface available
if not 'moduleDir' in globals():
    moduleDir = os.path.join(sgpp_folder,"lib")
    pysgpp_path = os.path.join(sgpp_folder,"lib/pysgpp")
    sys.path.append(moduleDir)
    sys.path.append(pysgpp_path)

sgpp_path = os.path.join(sgpp_folder,"lib/sgpp")

# do file fiddling necessary in colab so everything is found
# !sed -ie 's/^\(from . import extensions\)/try:\n    \1\nexcept:\n    import extensions/' $pysgpp_path/__init__.py
# !cp $sgpp_path/* /usr/lib

import pysgpp
# Make python interface available
if not 'moduleDir' in globals():
    moduleDir = os.path.join(sgpp_folder,"lib")
    pysgpp_path = os.path.join(sgpp_folder,"lib/pysgpp")
    sys.path.append(moduleDir)
    sys.path.append(pysgpp_path)

sgpp_path = os.path.join(sgpp_folder,"lib/sgpp")

# do file fiddling necessary in colab so everything is found
# !sed -ie 's/^\(from . import extensions\)/try:\n    \1\nexcept:\n    import extensions/' $pysgpp_path/__init__.py
# Out:
# sed: can't read /home/michael/coding/sparse-anova/notebooks/SGpp/lib/pysgpp/__init__.py: No such file or directory
